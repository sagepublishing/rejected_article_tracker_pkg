# %% [markdown]
# ## Test on MedRxiv data
#
# This is an insteresting test. We trained on ArXiv, so we shouldn't necessarily expect the tracker to perform well on data from another field.
#
# We need to make some adjustments to track MedRxiv because the RAT searches Crossref for articles. However, MedRxiv is already in Crossref, so we need to filter out the query-articles when they come up in the results.
#
# ## Reference
#
# The dataset comes from this Zenodo repository:
#
# Cabanac, Guillaume, Oikonomidi, Theodora, & Boutron, Isabelle. (2021). Day-to-day discovery of preprint–publication links [Data set]. In Scientometrics. Zenodo. https://doi.org/10.5281/zenodo.4432116

# %%
import pandas as pd
import os, json, requests

# %% [markdown]
# # Load the MedRxiv data

# %%
p = r'../../../data'
fp = os.path.join(p,'20200916-medRxiv_analysis.xlsx')
medrxiv = pd.read_excel(fp)
medrxiv.shape
# Out:
# (740, 13)

# %% [markdown]
# # First, use Crossref API to get correct data from medrxiv data
#
# This is the data we will use to check our results.

# %%
class CrossrefAPI:
    
    def __init__(self, doi):
        self.doi = doi
      
    def get_data(self):
        doi = self.doi
        api_resp = self.api_call(doi)
        output = self.selected_output(api_resp)
        return output
    
    @staticmethod
    def api_call(doi:str):
        base_url = 'https://api.crossref.org/works/'
        url = base_url+doi
        headers = {
            'User-Agent': "Analytics",
            'mailto': os.environ.get('MY_EMAIL','')
        }
        r = requests.get(url, headers = headers)
        if r.status_code == 200:
            try:
                crdata = r.json()
                if 'message' in crdata:
                    msg = crdata['message']
                    return msg
            except:
                pass
        return None
            
    def selected_output(self,msg):
        output = dict()
        output['title'] = msg.get('title',[''])[0]
        if len(output['title'])>0:
            authors = msg['author']
            if isinstance(authors,list):
                output['authors'] = self.authors_list(authors)
                output['DOI'] = msg['DOI']
                output['abstract'] = msg.get('abstract','')
                return output
            
    @staticmethod
    def authors_list(authors: list) -> list:
        match_authors = []
        for author in authors:
            given = author.get('given', '')
            family = author.get('family', '')
            match_authors.append(family + ', ' + given)
        return '; '.join(match_authors)

# %%
from tqdm import tqdm

testdf_path = os.path.join(p,'testdf.csv')
if os.path.exists(testdf_path):
    testdf = pd.read_csv(testdf_path)
else:

    test_data = []
    for i,row in tqdm(medrxiv.iterrows(),total = len(medrxiv)):
        output_row = dict()
        try:
            query_data = CrossrefAPI(row['DOI preprint']).get_data()
            match_data = CrossrefAPI(row['DOI publication']).get_data()
        except:
            query_data = None
            match_data= None
        if all(x!=None for x in (query_data,match_data)):
            for key in query_data:
                output_row['query_'+key] = query_data[key]
            for key in match_data:
                output_row['match_'+key] = match_data[key]
            test_data.append(output_row)
    testdf = pd.DataFrame(test_data)
    testdf.to_csv(testdf_path, index = False, encoding = 'utf-8-sig')
testdf.shape
# Out:
# (740, 8)

# %%
testdf.head(2)
# Out:
#                                          query_title  \
# 0  Optimising the use of molecular tools for the ...
# 1  The prevalence of scabies, pyoderma and other ...
#
#                                        query_authors         query_DOI  \
# 0  Munson, Morgan; Creswell, Benjamin; Kondobala,...  10.1101/19000232
# 1  Marks, Michael; Sammut, Thomas; Cabral, Marito...  10.1101/19000257
#
#                                       query_abstract  \
# 0  <jats:title>Abstract</jats:title><jats:sec><ja...
# 1  <jats:title>Abstract</jats:title><jats:sec><ja...
#
#                                          match_title  \
# 0  Optimising the use of molecular tools for the ...
# 1  The prevalence of scabies, pyoderma and other ...
#
#                                        match_authors  \
# 0  Munson, Morgan; Creswell, Benjamin; Kondobala,...
# 1  Marks, Michael; Sammut, Thomas; Cabral, Marito...
#
#                       match_DOI  \
# 0         10.1093/trstmh/trz083
# 1  10.1371/journal.pntd.0007820
#
#                                       match_abstract
# 0  <jats:title>Abstract</jats:title><jats:sec><ja...
# 1                                                NaN

# %%
# what % of abstracts are available?
# guessing there are more in pubmed than in crossref
n =len(testdf)
n_w_abstract = len(testdf[testdf['match_abstract'].isna()])
n, n_w_abstract, 1- ( n_w_abstract/ n)
# Out:
# (740, 462, 0.3756756756756757)

# %% [markdown]
# # Check RAT recall

# %%
def testdfrow_to_article(row):
    article = dict()
    article['Submission Date'] = '1900-01-01'
    article['Decision Date'] = '1900-01-01'
    article['Accept or Reject Final Decision'] = 'Reject'
    article['Manuscript ID'] = row['query_DOI']
    # article['query_doi'] = row['match_DOI']
    article['Manuscript Title'] = row['query_title']
    article['Journal Name'] = 'medrxiv'
    article['doi_number'] = row['match_DOI']
    article['Author Names'] = row['query_authors']
    article['abstract'] = row['query_abstract']
    return article
    
# sample_size = 1000 # len(testdf)
# articles = list(testdf.sample(sample_size, random_state =7).T.to_dict().values())
articles = list(testdf.T.to_dict().values())
articles = [testdfrow_to_article(row) for row in articles]
len(articles)
# Out:
# 740

# %%
from rejected_article_tracker.src.ScholarOneRejectedArticlesMatch import ScholarOneRejectedArticlesMatch
# for each row, run the RAT and see whether we get the DOI
# keep a running total of recall
config = {
                # from 0.0 - 1.0 
                # Set higher for better precision, lower for better recall
                "threshold": 0.0, 
                # any number from 1 - 10. If there are multiple versions of the article out there, it's worth picking  number >1
                "max_results_per_article":10, 
                # limit results to these types see: https://api.crossref.org/types
                "article_types":[],
            }
# The CrossRef API requires an email address for lookups.    
email = os.getenv('MY_EMAIL')
# Define a 'results' list.
results = []

# Run match
ScholarOneRejectedArticlesMatch(
    articles=articles,
    config=config,
    email=email,
    results=results
).match()

result_df = pd.DataFrame(results)

len(result_df)
# Out:
# 6287

# %%
# add the correct DOIs that we were searching for

result_df = result_df.merge(testdf[['query_DOI','match_DOI']].rename(columns={'match_DOI':'correct_doi'}),
                            left_on = 'manuscript_id', 
                            right_on='query_DOI', 
                            how = 'left')
result_df = result_df.drop(['query_DOI'], axis = 1)
result_df.head(2)
# Out:
#       manuscript_id raw_manuscript_id journal_name  \
# 0  10.1101/19000232  10.1101/19000232      medrxiv
# 1  10.1101/19000232  10.1101/19000232      medrxiv
#
#                                     manuscript_title  \
# 0  Optimising the use of molecular tools for the ...
# 1  Optimising the use of molecular tools for the ...
#
#                                 title_for_search submission_date  \
# 0  Optimising use molecular tools diagnosis yaws      1900-01-01
# 1  Optimising use molecular tools diagnosis yaws      1900-01-01
#
#   decision_date                                            authors  \
# 0    1900-01-01  Morgan+Munson, Benjamin+Creswell, Kofi+Kondoba...
# 1                Morgan+Munson, Benjamin+Creswell, Kofi+Kondoba...
#
#   text_sub_date final_decision  ...   match_earliest_date match_similarity  \
# 0    1900-01-01         Reject  ...  2019-07-24T00:00:00Z               97
# 1    1900-01-01         Reject  ...  2019-06-25T00:00:00Z               97
#
#   match_one match_all classifier_score match_crossref_score  \
# 0         1         0         0.873461            177.03232
# 1         1         1         0.961794            185.34901
#
#   match_crossref_cites match_rank match_total_decision_days  \
# 0                    0          1                     43668
# 1                    0          2                         0
#
#              correct_doi
# 0  10.1093/trstmh/trz083
# 1  10.1093/trstmh/trz083
#
# [2 rows x 27 columns]

# %%
p = r'../../../data'
fp = os.path.join(p,'resultdf.csv')
result_df.to_csv(fp,index=False,encoding ='utf-8-sig')

# %%
# filter out the preprints themselves

result_df = result_df[ result_df['manuscript_id'] != result_df['match_doi'] ]

# %%
# articles[0]

# %%
cols = ['manuscript_id',
       'manuscript_title', 'authors',
       'correct_doi', 'match_doi',
       'match_type', 'match_title', 'match_authors', 'match_publisher',
       'match_journal', 'match_pub_date', 'match_earliest_date',
       'match_similarity', 'match_one', 'match_all', 'match_crossref_score',
       'match_crossref_cites', 'match_rank', 'match_total_decision_days',
       'classifier_score',
       'correct']

# %%
result_df.head(2)
# Out:
#       manuscript_id raw_manuscript_id journal_name  \
# 0  10.1101/19000232  10.1101/19000232      medrxiv
# 2  10.1101/19000232  10.1101/19000232      medrxiv
#
#                                     manuscript_title  \
# 0  Optimising the use of molecular tools for the ...
# 2  Optimising the use of molecular tools for the ...
#
#                                 title_for_search submission_date  \
# 0  Optimising use molecular tools diagnosis yaws      1900-01-01
# 2  Optimising use molecular tools diagnosis yaws      1900-01-01
#
#   decision_date                                            authors  \
# 0    1900-01-01  Morgan+Munson, Benjamin+Creswell, Kofi+Kondoba...
# 2                Morgan+Munson, Benjamin+Creswell, Kofi+Kondoba...
#
#   text_sub_date final_decision  ...   match_earliest_date match_similarity  \
# 0    1900-01-01         Reject  ...  2019-07-24T00:00:00Z               97
# 2    1900-01-01         Reject  ...  2020-02-23T00:00:00Z               38
#
#   match_one match_all classifier_score match_crossref_score  \
# 0         1         0         0.873461            177.03232
# 2         1         0         0.001209             35.34102
#
#   match_crossref_cites match_rank match_total_decision_days  \
# 0                    0          1                     43668
# 2                    0          4                         0
#
#              correct_doi
# 0  10.1093/trstmh/trz083
# 2  10.1093/trstmh/trz083
#
# [2 rows x 27 columns]

# %%
result_df['correct'] = result_df['match_doi']==result_df['correct_doi']
correct_dois = set(testdf['match_DOI'])
threshold = 0.5

crossref_recall = result_df[(result_df['match_doi'].isin(correct_dois))]['match_doi'].nunique() / len(correct_dois)
correct_results = result_df[(result_df['classifier_score']>=threshold) & (result_df['match_doi'].isin(correct_dois))]
n_true_positives = correct_results['manuscript_id'].nunique()

# check ML specifically
results_that_ml_can_find = result_df[(result_df['match_doi'].isin(correct_dois))]['match_doi'].unique()
results_ml_found = result_df[(result_df['classifier_score']>=threshold)&(result_df['match_doi'].isin(correct_dois))]['match_doi']
ml_recall = len(results_ml_found) / len(results_that_ml_can_find)

n_false_positives = len(result_df[(result_df['classifier_score']>=threshold) & (~result_df['match_doi'].isin(correct_dois))])
n_false_neg = len(result_df[(result_df['classifier_score']<threshold) & (result_df['match_doi'].isin(correct_dois))])

precision = n_true_positives / (n_true_positives+n_false_positives)
recall = n_true_positives / len(correct_dois)

output = [
dict(label='Number of MedRxiv preprints', value=len(testdf)),
dict(label='Results from RAT search', value=len(result_df)),
dict(label='Crossref\'s recall', value=crossref_recall),
dict(label='Max possible correct results', value=len(correct_dois)),
dict(label='ML recall', value=ml_recall),
dict(label='TP', value=n_true_positives),
dict(label='FP', value=n_false_positives),
dict(label='FN', value=n_false_neg),
dict(label='RAT recall', value=recall),
dict(label='RAT precision', value=precision),
]
pd.DataFrame(output)
# Out:
#                           label        value
# 0   Number of MedRxiv preprints   740.000000
# 1       Results from RAT search  5549.000000
# 2             Crossref's recall     0.987838
# 3  Max possible correct results   740.000000
# 4                     ML recall     0.923393
# 5                            TP   675.000000
# 6                            FP   117.000000
# 7                            FN   128.000000
# 8                    RAT recall     0.912162
# 9                 RAT precision     0.852273

# %%
# check incorrect results
result_df[(result_df['match_doi']!='No Match')&(result_df['correct']==False)][cols]
# Out:
#                     manuscript_id  \
# 2                10.1101/19000232
# 3                10.1101/19000232
# 4                10.1101/19000232
# 5                10.1101/19000232
# 8                10.1101/19000257
# ...                           ...
# 6282  10.1101/2020.07.05.20146878
# 6283  10.1101/2020.07.05.20146878
# 6284  10.1101/2020.07.05.20146878
# 6285  10.1101/2020.07.05.20146878
# 6286  10.1101/2020.07.05.20146878
#
#                                        manuscript_title  \
# 2     Optimising the use of molecular tools for the ...
# 3     Optimising the use of molecular tools for the ...
# 4     Optimising the use of molecular tools for the ...
# 5     Optimising the use of molecular tools for the ...
# 8     The prevalence of scabies, pyoderma and other ...
# ...                                                 ...
# 6282  Effect of Systemic Inflammatory Response to SA...
# 6283  Effect of Systemic Inflammatory Response to SA...
# 6284  Effect of Systemic Inflammatory Response to SA...
# 6285  Effect of Systemic Inflammatory Response to SA...
# 6286  Effect of Systemic Inflammatory Response to SA...
#
#                                                 authors  \
# 2     Morgan+Munson, Benjamin+Creswell, Kofi+Kondoba...
# 3     Morgan+Munson, Benjamin+Creswell, Kofi+Kondoba...
# 4     Morgan+Munson, Benjamin+Creswell, Kofi+Kondoba...
# 5     Morgan+Munson, Benjamin+Creswell, Kofi+Kondoba...
# 8     Michael+Marks, Thomas+Sammut, Marito Gomes+Cab...
# ...                                                 ...
# 6282  Catia+Marzolini, Felix+Stader, Marcel+Stoeckle...
# 6283  Catia+Marzolini, Felix+Stader, Marcel+Stoeckle...
# 6284  Catia+Marzolini, Felix+Stader, Marcel+Stoeckle...
# 6285  Catia+Marzolini, Felix+Stader, Marcel+Stoeckle...
# 6286  Catia+Marzolini, Felix+Stader, Marcel+Stoeckle...
#
#                        correct_doi                         match_doi  \
# 2            10.1093/trstmh/trz083       10.1101/2020.02.20.20025122
# 3            10.1093/trstmh/trz083        10.3390/tropicalmed5040157
# 4            10.1093/trstmh/trz083  10.20944/preprints202008.0569.v1
# 5            10.1093/trstmh/trz083       10.1007/978-3-319-43148-2_5
# 8     10.1371/journal.pntd.0007820             10.1093/trstmh/trz102
# ...                            ...                               ...
# 6282          10.1128/aac.01177-20       10.1101/2020.07.07.20148163
# 6283          10.1128/aac.01177-20                 10.1002/jmv.26731
# 6284          10.1128/aac.01177-20       10.1101/2020.09.22.20198697
# 6285          10.1128/aac.01177-20        10.1186/s13756-021-00912-z
# 6286          10.1128/aac.01177-20     10.3390/microorganisms9051094
#
#            match_type                                        match_title  \
# 2      posted-content  Mapping of yaws endemicity in Ghana; Lessons t...
# 3     journal-article  Multiplex Recombinase Polymerase Amplification...
# 4      posted-content  Multiplex Recombinase Polymerase Amplification...
# 5        book-chapter  Yaws in Oceania: New Tools for the Global Erad...
# 8     journal-article  Perceptions, attitudes and practices towards s...
# ...               ...                                                ...
# 6282   posted-content  Epidemiology of SARS-CoV-2 Emergence Amidst Co...
# 6283  journal-article  Epidemiology and precision of SARS‐CoV‐2 detec...
# 6284   posted-content  Epidemiology and precision of SARS-CoV-2 detec...
# 6285  journal-article  Systematic screening on admission for SARS-CoV...
# 6286  journal-article  Global Genomic Analysis of SARS-CoV-2 RNA Depe...
#
#                                           match_authors  \
# 2     Laud Anthony Wihibeturo+Basing, Moses+Djan, Sh...
# 3     Michael+Frimpong, Shirley Victoria+Simpson, Hu...
# 4     Michael+Frimpong, Shirley Victoria+Simpson, Hu...
# 5                            Oriol+Mitjà, Michael+Marks
# 8     Maria João+Lopes, Eunice Teixeira+da Silva, Ja...
# ...                                                 ...
# 6282  Karoline+Leuzinger, Tim+Roloff, Rainer+Gosert,...
# 6283  Karoline+Leuzinger, Rainer+Gosert, Kirstine K....
# 6284  Karoline+Leuzinger, Rainer+Gosert, Kirstine K....
# 6285  Rahel N.+Stadler, Laura+Maurer, Lisandra+Aguil...
# 6286  Alfredo+Mari, Tim+Roloff, Madlen+Stange, Kirst...
#
#                               match_publisher  \
# 2               Cold Spring Harbor Laboratory
# 3                                     MDPI AG
# 4                                     MDPI AG
# 5           Springer International Publishing
# 8               Oxford University Press (OUP)
# ...                                       ...
# 6282            Cold Spring Harbor Laboratory
# 6283                                    Wiley
# 6284            Cold Spring Harbor Laboratory
# 6285  Springer Science and Business Media LLC
# 6286                                  MDPI AG
#
#                                           match_journal  ...  \
# 2                                                        ...
# 3              Tropical Medicine and Infectious Disease  ...
# 4                                                        ...
# 5                           Neglected Tropical Diseases  ...
# 8     Transactions of The Royal Society of Tropical ...  ...
# ...                                                 ...  ...
# 6282                                                     ...
# 6283                        Journal of Medical Virology  ...
# 6284                                                     ...
# 6285   Antimicrobial Resistance &amp; Infection Control  ...
# 6286                                     Microorganisms  ...
#
#        match_earliest_date match_similarity match_one match_all  \
# 2     2020-02-23T00:00:00Z               38         1         0
# 3     2020-10-06T00:00:00Z               34         1         0
# 4     2020-08-26T00:00:00Z               35         1         0
# 5     2016-01-01T00:00:00Z               43         1         0
# 8     2019-08-31T00:00:00Z               56         1         0
# ...                    ...              ...       ...       ...
# 6282  2020-07-08T00:00:00Z               40         1         0
# 6283  2020-12-14T00:00:00Z               43         1         0
# 6284  2020-09-23T00:00:00Z               45         1         0
# 6285  2021-02-27T00:00:00Z               46         1         0
# 6286  2021-05-19T00:00:00Z               42         1         0
#
#      match_crossref_score match_crossref_cites match_rank  \
# 2                35.34102                    0          4
# 3                 34.5222                    2          5
# 4               35.191635                    0          6
# 5                33.94325                    0          8
# 8               120.58603                    1          3
# ...                   ...                  ...        ...
# 6282            59.176453                    3          6
# 6283            57.969116                   10          7
# 6284             58.97999                    1          8
# 6285            54.175335                    7          9
# 6286             51.21843                    7         10
#
#      match_total_decision_days classifier_score  correct
# 2                            0         0.001209    False
# 3                            0         0.000673    False
# 4                            0         0.000779    False
# 5                            0         0.002512    False
# 8                            0         0.016572    False
# ...                        ...              ...      ...
# 6282                         0         0.001628    False
# 6283                         0         0.002525    False
# 6284                         0         0.003382    False
# 6285                         0         0.003914    False
# 6286                         0         0.002181    False
#
# [4816 rows x 21 columns]
